# %% [markdown]
# ### Import Data Notebook
#
# This notebook should give me an easily accessible way of importing data from the large dataset in Snowflake to my own custom tables

# %%
import sys, os
import pandas as pd
import numpy as np
from dotenv import load_dotenv

sys.path.append('/Users/katringrunert/Projects/Uni/thesis/neuro-symbolic-demand-forecasting')
# when running on JupyterHub the dot-env-path needs to be adapted
load_dotenv("../.env")

datetime_format = "%Y-%m-%d %H:%M%z"

from src.neuro_symbolic_demand_forecasting.database.weather_postgres import WeatherDao
from src.neuro_symbolic_demand_forecasting.database.snowflake import SnowflakeDao


sf_dao = SnowflakeDao(
    url=os.getenv("SNOWFLAKE_URL"),
    uid=os.getenv("SNOWFLAKE_UID"),
    pwd=os.getenv("SNOWFLAKE_PASSWORD"),
    database=os.getenv("SNOWFLAKE_DATABASE"),
    schema=os.getenv("SNOWFLAKE_SCHEMA"),
)
pg_dao = WeatherDao(
    url=os.getenv("POSTGRES_HOST_WEATHER_DATA"),
    uid=os.getenv("POSTGRES_UID_WEATHER_DATA"),
    pwd=os.getenv("POSTGRES_PASSWORD_WEATHER_DATA"),
    database=os.getenv("POSTGRES_DATABASE_WEATHER_DATA"),
    schema=os.getenv("POSTGRES_SCHEMA_WEATHER_DATA"),
    port=int(os.getenv("POSTGRES_PORT_WEATHER_DATA"))
)
sf_dao.connect()
pg_dao.connect()
# Out:
# Connected to snowflake instance!
# Connected to postgres host!

# %% [markdown]
# ## Subsampling from ACTIVE_CONTRACT_DATA (old and big) to CONTRACT_DATA (new and smaller)

# %%
contract_df = sf_dao.fetch_list("SELECT * FROM SANDBOX.KATRIN.ACTIVE_CONTRACT_DATA")
contract_df
# Out:
#       clusterreference degreeofisolation  hassolarpanels  solarpanelswattpeak  \
# 0             1068WG15           Average           False                  0.0
# 1           8426AC19-A           Average           False                  0.0
# 2        6718XB5-Nieuw              Good            True                  0.0
# 3            2678ZP127              Good            True               1320.0
# 4             1181VG56              Good            True                  4.0
# ...                ...               ...             ...                  ...
# 17029       3039SR25-B           Average           False                  0.0
# 17030          4531HW6           Average           False                  0.0
# 17031         8913GV19              Poor           False                  0.0
# 17032         6351JG33           Average            True                  0.0
# 17033         9722XC14              Poor           False                  0.0
#
#       surfacearea   typeofhouse  yearbuilt numberofpeople  \
# 0          From50   CornerHouse   From1946          Three
# 1          From15  SemiDetached   From1975            Two
# 2         From200      Detached   From2015          Three
# 3         From100      RowHouse   From2015            Two
# 4         From150      RowHouse   From1946          Three
# ...           ...           ...        ...            ...
# 17029      From50     Apartment  Until1945            Two
# 17030      From50     Apartment   From1975            One
# 17031      From15   CornerHouse  Until1945            One
# 17032     From150  SemiDetached   From1946           Four
# 17033      From50     Apartment   From1975            One
#
#                               connection_id                 ean  ...  \
# 0      fa3814dc-a4eb-4153-88ba-ae580114d07b  871685900008617662  ...
# 1      eca5959e-c22e-4658-86bd-a72901420930  871687120052650035  ...
# 2      7c0fc9ba-7638-4da8-a691-adb700d14346  871687110004168671  ...
# 3      d6b658c4-58ad-4364-8d20-afcf00aae00f  871687800001680992  ...
# 4      2eaf249f-0b7c-40c4-b3ce-ac4b00ddb45a  871685900009562541  ...
# ...                                     ...                 ...  ...
# 17029  718a6b95-b89e-4a82-bd80-b00a00a28e17  871689290101026123  ...
# 17030  c2198c6e-e0c8-4666-a9b3-ab0f014edc80  871690200022422658  ...
# 17031  108fd278-86d6-47f0-8955-abf700f2d183  871689740000025616  ...
# 17032  6f60138a-033e-4894-80f0-acdb0104569b  871688540000224191  ...
# 17033  1dc9631c-8176-41e5-98c7-aa1f00f0076b  871694840003784601  ...
#
#       contract_end_date contract_state pricing_type market_segment  \
# 0            2024-10-17         Active        Fixed    Electricity
# 1            2024-04-06         Active        Fixed    Electricity
# 2            2024-04-02         Active        Fixed    Electricity
# 3            2024-04-05         Active        Fixed    Electricity
# 4            2024-10-30         Active        Fixed    Electricity
# ...                 ...            ...          ...            ...
# 17029        2024-05-23         Active        Fixed    Electricity
# 17030        2024-05-15         Active        Fixed    Electricity
# 17031        2024-09-22         Active        Fixed    Electricity
# 17032        2024-05-24         Active        Fixed    Electricity
# 17033        2024-05-14         Active        Fixed    Electricity
#
#                         connection_group_id customer_size zip_code  \
# 0      70dacb49-3ae3-496f-8319-ae580114d068         Small     1068
# 1      577c4d5b-fd03-4d26-8ecf-a729014208ee         Small     8426
# 2      08e48d02-88d5-4a36-a358-adb700d0ed9d         Small     6718
# 3      7ad83cb4-2a48-44b7-8ba5-afcf00aae00f         Small     2678
# 4      382fe708-2ddf-4d28-b4f6-ac4b00ddb45a         Small     1181
# ...                                     ...           ...      ...
# 17029  6044d5f2-5002-42f0-ae19-b00a00a28e17         Small     3039
# 17030  dc18e5c9-79cf-414e-81a6-ab0f014edc80         Small     4531
# 17031  4182b295-ba28-412b-ab14-abf700f2d183         Small     8913
# 17032  96797ac0-4da2-4b01-8492-acdb0104569b         Small     6351
# 17033  78b2667e-8e0d-48c5-a999-aa1f00f0076b         Small     9722
#
#              city zip_code_suffixed       last_modified
# 0       AMSTERDAM           1068 WG 2024-03-19 10:42:02
# 1       APPELSCHA           8426 AC 2024-03-19 10:42:02
# 2         EDE GLD           6718 XB 2024-03-19 10:42:02
# 3         DE LIER           2678 ZP 2024-03-19 10:42:02
# 4      AMSTELVEEN           1181 VG 2024-03-19 10:42:02
# ...           ...               ...                 ...
# 17029   ROTTERDAM           3039 SR 2024-03-19 10:44:05
# 17030   TERNEUZEN           4531 HW 2024-03-19 10:44:05
# 17031  LEEUWARDEN           8913 GV 2024-03-19 10:44:05
# 17032    BOCHOLTZ           6351 JG 2024-03-19 10:44:05
# 17033   GRONINGEN           9722 XC 2024-03-19 10:44:05
#
# [17034 rows x 26 columns]

# %%
import datetime
contract_df['runtime_total'] = (contract_df['contract_end_date'] - contract_df['contract_start_date']).apply(lambda x: x.days)
contract_df['runtime_until_now'] = contract_df['contract_start_date'].apply(lambda x: (datetime.datetime(2024,1,1,0,0) - x).days)
contract_df[['runtime_total', 'runtime_until_now', 'contract_end_date', 'contract_start_date']].head()
# Out:
#    runtime_total  runtime_until_now contract_end_date contract_start_date
# 0            947                657        2024-10-17          2022-03-15
# 1            366                270        2024-04-06          2023-04-06
# 2            822                730        2024-04-02          2022-01-01
# 3            366                271        2024-04-05          2023-04-05
# 4           1096                793        2024-10-30          2021-10-30

# %%
filtered_df = contract_df[contract_df['runtime_until_now']>730]#[['runtime_total', 'runtime_until_now', 'contract_start_date', 'contract_end_date']]
print(filtered_df['contract_start_date'].max())
filtered_df[['runtime_total', 'runtime_until_now', 'contract_start_date', 'contract_end_date']]
# Out:
# 2021-12-31 00:00:00
#        runtime_total  runtime_until_now contract_start_date contract_end_date
# 4               1096                793          2021-10-30        2024-10-30
# 8               1096                754          2021-12-08        2024-12-08
# 9               1096                883          2021-08-01        2024-08-01
# 10              1035                914          2021-07-01        2024-05-01
# 15              1096                941          2021-06-04        2024-06-04
# ...              ...                ...                 ...               ...
# 17016           1096                937          2021-06-08        2024-06-08
# 17017           1096                944          2021-06-01        2024-06-01
# 17018           1096                907          2021-07-08        2024-07-08
# 17022           1096                822          2021-10-01        2024-10-01
# 17032           1096                952          2021-05-24        2024-05-24
#
# [5842 rows x 4 columns]

# %%
# Samples:  15205 	 PV:  39.97  	Non-PV: 60.03
# aim to upkeep this ratio
pv=39/100.0
non_pv=1-pv

len(filtered_df[filtered_df['hassolarpanels']])/len(filtered_df), len(filtered_df[~filtered_df['hassolarpanels']])/len(filtered_df)
# Out:
# (0.41783635741184527, 0.5821636425881548)

# %%
pv_total = len(filtered_df[filtered_df['hassolarpanels']])
nonpv_totla = len(filtered_df[~filtered_df['hassolarpanels']])
total = len(filtered_df)

# pv_total, int(total*pv)
print((total-int(total*pv))/total)
print(int(total*pv))
subsampled = pd.concat([filtered_df[filtered_df['hassolarpanels']].sample(n=int(total*pv)-100), filtered_df[~filtered_df['hassolarpanels']]])
subsampled
# Out:
# 0.6100650462170489
# 2278
#       clusterreference degreeofisolation  hassolarpanels  solarpanelswattpeak  \
# 3944          1115GD50           Average            True                  0.0
# 3953          6581CV14           Average            True               1650.0
# 4622         2693EA117              Good            True               2880.0
# 4138           9651CN7           Average            True                 18.0
# 7379          1602JB17              Good            True               3000.0
# ...                ...               ...             ...                  ...
# 17014     6824BG47-402              Good           False                  0.0
# 17016          3448CA5              Poor           False                  0.0
# 17017         6462GT37           Average           False                  0.0
# 17018          7161RB5           Average           False                  0.0
# 17022          3402GN4              Poor           False                  0.0
#
#       surfacearea   typeofhouse  yearbuilt numberofpeople  \
# 3944      From100      RowHouse   From1975     FiveOrMore
# 3953      From150  SemiDetached   From1965           Four
# 4622      From100      RowHouse   From2015           Four
# 4138      From100      Detached  Until1945            Two
# 7379      From100   CornerHouse   From1975            Two
# ...           ...           ...        ...            ...
# 17014      From50     Apartment   From2015            One
# 17016      From15     Apartment   From1975            One
# 17017      From50     Apartment   From1975            One
# 17018     From250      Detached  Until1945            Two
# 17022     From100   CornerHouse   From1965            Two
#
#                               connection_id                 ean  ...  \
# 3944   68ce711c-9591-4037-a559-a7c100c0514b  871685900009338870  ...
# 3953   17a34041-7cf5-4dee-a24d-ac5700fe2c13  871687120053936725  ...
# 4622   f2f0b7b6-0166-4544-8d7b-ace500ab1448  871687800001648695  ...
# 4138   75e3c479-2b91-45d2-8e90-ac3a00f32651  871694840004711163  ...
# 7379   65bfaff3-fb48-47eb-8766-a6a700e907ca  871685900004513234  ...
# ...                                     ...                 ...  ...
# 17014  dc6a400a-bee8-46cb-9be8-ad3900ef53b9  871687110003927996  ...
# 17016  8f779647-e29a-49e8-a017-a8d501480eca  871687400005418999  ...
# 17017  e5ca7e4a-4e56-41f9-8301-ad2800ee5ec2  871688540003383000  ...
# 17018  c06df8e5-fea2-4357-adf4-a99300a32722  871687120055934361  ...
# 17022  54f4d202-e9b9-4b66-bf58-ad6500c95bdf  871687400003001681  ...
#
#       pricing_type market_segment                   connection_group_id  \
# 3944         Fixed    Electricity  c4d6d8b3-5e64-4378-82b3-a7c100c050d1
# 3953         Fixed    Electricity  c237f756-1934-4e7e-89f9-ac5700fe2c13
# 4622         Fixed    Electricity  eea5f333-513d-4c14-8850-ace500ab1448
# 4138         Fixed    Electricity  2c39d841-b4e0-4fb5-b3bd-ac3a00f32651
# 7379         Fixed    Electricity  0c5d50b7-7acb-4f87-9e9f-a6a700e907a9
# ...            ...            ...                                   ...
# 17014        Fixed    Electricity  3268ee71-efd9-41c4-98c8-ad3900ef53b9
# 17016        Fixed    Electricity  8fb15b1c-c2de-459c-b773-a8d501480eca
# 17017        Fixed    Electricity  6bdba9cf-d4cc-410a-a7e5-ad2800ee5ec2
# 17018        Fixed    Electricity  0f2593f2-0286-454b-8d06-a99300a32722
# 17022        Fixed    Electricity  dfc9195f-6823-4788-a21d-ad6500c95bdf
#
#       customer_size zip_code            city zip_code_suffixed  \
# 3944          Small     1115    DUIVENDRECHT           1115 GD
# 3953          Small     6581          MALDEN           6581 CV
# 4622          Small     2693  'S-GRAVENZANDE           2693 EA
# 4138          Small     9651          MEEDEN           9651 CN
# 7379          Small     1602       ENKHUIZEN           1602 JB
# ...             ...      ...             ...               ...
# 17014         Small     6824          ARNHEM           6824 BG
# 17016         Small     3448         WOERDEN           3448 CA
# 17017         Small     6462        KERKRADE           6462 GT
# 17018         Small     7161           NEEDE           7161 RB
# 17022         Small     3402     IJSSELSTEIN           3402 GN
#
#             last_modified runtime_total runtime_until_now
# 3944  2024-03-19 10:44:05          1096              1003
# 3953  2024-03-19 10:44:05          1096               775
# 4622  2024-03-19 10:44:05          1096               960
# 4138  2024-03-19 10:44:05          1096               832
# 7379  2024-03-19 10:44:05          1096               765
# ...                   ...           ...               ...
# 17014 2024-03-19 10:44:05          1096               938
# 17016 2024-03-19 10:44:05          1096               937
# 17017 2024-03-19 10:44:05          1096               944
# 17018 2024-03-19 10:44:05          1096               907
# 17022 2024-03-19 10:44:05          1096               822
#
# [5579 rows x 28 columns]

# %%
len(subsampled[subsampled['hassolarpanels']])/len(subsampled), len(subsampled[~subsampled['hassolarpanels']])/len(subsampled)
# Out:
# (0.3903925434665711, 0.609607456533429)

# %%
df_for_insert = subsampled[['clusterreference',
 'degreeofisolation',
 'hassolarpanels',
 'solarpanelswattpeak',
 'surfacearea',
 'typeofhouse',
 'yearbuilt',
 'numberofpeople',
 'connection_id',
 'ean',
 'ean_sha256',
 'previous_contract_id',
 'contract_id',
 'initial_contract_id',
 'parent_contract_id',
 'contract_start_date',
 'contract_end_date',
 'contract_state',
 'pricing_type',
 'market_segment',
 'connection_group_id',
 'customer_size',
 'zip_code',
 'city',
 'zip_code_suffixed',
 'last_modified']]


df_for_insert['last_modified'] = datetime.datetime.now()
df_for_insert.columns = [column.upper() for column in df_for_insert.columns]

df_for_insert.reset_index(inplace=True, drop=True)
df_for_insert['CONTRACT_START_DATE'] = df_for_insert['CONTRACT_START_DATE'].apply(lambda x: x.strftime('%Y-%m-%d'))
df_for_insert['CONTRACT_END_DATE'] = df_for_insert['CONTRACT_END_DATE'].apply(lambda x: x.strftime('%Y-%m-%d'))
df_for_insert['LAST_MODIFIED'] = df_for_insert['LAST_MODIFIED'].apply(lambda x: x.strftime('%Y-%m-%d %H:%M:%S'))
df_for_insert
# Out:
# /var/folders/ks/_jlbnqgn7ks2yq2nrk1jy21w0000gp/T/ipykernel_86463/335094463.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_for_insert['last_modified'] = datetime.datetime.now()

# %% [markdown]
# ## Import Timeseries

# %%
from src.neuro_symbolic_demand_forecasting.helpers import constants
from snowflake.connector.pandas_tools import write_pandas
import snowflake.connector as sc

snowflake_connection = sc.connect(
    user=os.getenv("SNOWFLAKE_UID"),
    password=os.getenv("SNOWFLAKE_PASSWORD"),
    account=os.getenv("SNOWFLAKE_URL"),
    warehouse='USER_WH',
    # region=self.snowflake_parameters.region,
    schema="KATRIN",
    database="SANDBOX",
    role="DATA_ENGINEER",
)
# write_pandas(
#     conn=snowflake_connection,
#     df=df_for_insert,
#     table_name="CONTRACT_DATA"
# )
contract_df = sf_dao.fetch_list("SELECT * FROM SANDBOX.KATRIN.CONTRACT_DATA")
contract_df

# %%
eans = [f"'{e.upper()}'"for e in contract_df['ean_sha256'].tolist()]
# month,year = 2, 2023
# table_name = "P4_METERREADING_WINTER"
# so far:
# 1, 2022, 2023
# 2, 2022, 2023
# 3, 2022
# 10, 2022
# 11, 2022
# 12, 2022

table_name = "P4_METERREADING_SUMMER"
# DONE
# month,year = 5, 2023
# month,year = 5, 2023
# month,year = 6, 2022
# month,year = 6, 2023
month,year = 7, 2022

# TBD 
# month,year = 7, 2023
# month,year = 8, 2023
# month,year = 8, 2022

# %%
i, batch_size = 0, 2000

print("For", month, year)
acc = pd.DataFrame()
while i < len(eans):
    print(i, i+batch_size)
    if i+batch_size > len(eans):
        print("Last one!")
        sub_eans = eans[i:]
    else:
        sub_eans = eans[i:i+batch_size]
    _df = sf_dao.fetch_list(f"""SELECT EAN_SHA256, LDN, ODN, READINGDATE, MEASUREUNIT, METERNUMBER
                             FROM P4.RAW.INTERVAL WHERE 
                    EAN_SHA256 IN ({','.join(sub_eans)}) 
                    AND READINGDATE LIKE '{month}/%/{year}%'
                    """)
    print("Done")
    i += batch_size
    acc = pd.concat([acc, _df])

acc
# Out:
# For 7 2022
# 0 2000
# Done
# 2000 4000
# Done
# 4000 6000
# Last one!
# Done
#                                                 ean_sha256           ldn  \
# 0        28748B27AD94B6E3D1C92B98A3ED1A22DE546D2DCDE19F...  13453957.000
# 1        BEA11819BC86FEA2B546185FD90BAC0086B39E74F5F781...   2167396.000
# 2        BA70E201877E99246FCA6858D18FBB6E29371AFB2A49EC...  39562698.000
# 3        FE8180B19B478AEBF15F4C00688EA31F2C15688D95555B...  21080148.000
# 4        03B46BD7E6E5D728FE386C9D19DFA118CE5FF167D08FF2...   3808310.000
# ...                                                    ...           ...
# 4254422  2A65128A7457D123615AE92502AD030F1AF3F861B3D835...   6161072.000
# 4254423  2A65128A7457D123615AE92502AD030F1AF3F861B3D835...   6162718.000
# 4254424  2A65128A7457D123615AE92502AD030F1AF3F861B3D835...   6161265.000
# 4254425  2A65128A7457D123615AE92502AD030F1AF3F861B3D835...   6162630.000
# 4254426  2A65128A7457D123615AE92502AD030F1AF3F861B3D835...   6156874.000
#
#                   odn                   readingdate  measureunit  \
# 0         2411113.000   7/1/2022 12:00:00 AM +02:00            5
# 1          853843.000   7/1/2022 12:00:00 AM +02:00            5
# 2         9817698.000   7/1/2022 12:00:00 AM +02:00            5
# 3        12219335.000   7/1/2022 12:00:00 AM +02:00            5
# 4        10523717.000   7/1/2022 12:00:00 AM +02:00            5
# ...               ...                           ...          ...
# 4254422         0.000   7/20/2022 3:00:00 PM +02:00            5
# 4254423         0.000   7/20/2022 8:30:00 PM +02:00            5
# 4254424         0.000   7/20/2022 3:30:00 PM +02:00            5
# 4254425         0.000   7/20/2022 8:15:00 PM +02:00            5
# 4254426         0.000  7/20/2022 12:30:00 AM +02:00            5
#
#                meternumber
# 0        E0054007719013020
# 1        E0054008371493921
# 2        E0026000018774115
# 3        E0031003239459516
# 4        E0054008380528921
# ...                    ...
# 4254422  E0051005318875519
# 4254423  E0051005318875519
# 4254424  E0051005318875519
# 4254425  E0051005318875519
# 4254426  E0051005318875519
#
# [15101079 rows x 6 columns]

# %%
import datetime
acc['readingdate'] = pd.to_datetime(acc['readingdate'], format="%m/%d/%Y %I:%M:%S %p %z")
acc['readingdate'] = acc['readingdate'].apply(lambda x: x.strftime('%Y-%m-%d %H:%M:%S%z'))
acc['last_modified'] = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

acc.sort_values(by='readingdate', inplace=True)
acc['ldn'] = acc['ldn'].astype(float) 
acc['odn'] = acc['odn'].astype(float)
acc['ldn_diff'] = acc.groupby('ean_sha256')['ldn'].diff()
acc['odn_diff'] = acc.groupby('ean_sha256')['odn'].diff()

# %%
acc.columns = [column.upper() for column in acc.columns]
write_pandas(
    conn=snowflake_connection,
    df=acc[['EAN_SHA256','LDN','ODN','READINGDATE','METERNUMBER','LDN_DIFF','ODN_DIFF', 'LAST_MODIFIED']],
    chunk_size=200000,
    table_name=table_name
)
# Out:
# /var/folders/ks/_jlbnqgn7ks2yq2nrk1jy21w0000gp/T/ipykernel_35299/2150738713.py:2: UserWarning: Pandas Dataframe has non-standard index of type <class 'pandas.core.indexes.base.Index'> which will not be written. Consider changing the index to pd.RangeIndex(start=0,...,step=1) or call reset_index() to keep index as column(s)
#   write_pandas(
# (True,
#  76,
#  15101079,
#  [('sxcxlyqgsj/file10.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file2.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file24.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file32.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file40.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file46.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file52.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file60.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file7.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file0.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file22.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file3.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file36.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file43.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file51.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file58.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file66.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file73.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file13.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file20.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file27.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file35.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file42.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file5.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file57.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file64.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file71.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file1.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file21.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file28.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file37.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file44.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file50.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file59.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file65.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file72.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file14.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file18.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file29.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file33.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file41.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file47.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file56.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file61.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file70.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file75.txt',
#    'LOADED',
#    101079,
#    101079,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file12.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file16.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file23.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file30.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file38.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file45.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file53.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file6.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file67.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file74.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file15.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file17.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file26.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file34.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file39.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file48.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file54.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file62.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file69.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file8.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file11.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file19.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file25.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file31.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file4.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file49.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file55.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file63.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file68.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None),
#   ('sxcxlyqgsj/file9.txt',
#    'LOADED',
#    200000,
#    200000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None)])

# %%
df = sf_dao.fetch_list(f"SELECT * FROM SANDBOX.KATRIN.P4_METERREADING_SUMMER WHERE READINGDATE>='2023-05-01 00:00+02:00' AND READINGDATE<='2023-05-15 00:00+02:00'")
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = sf_dao.fetch_list(f"SELECT * FROM SANDBOX.KATRIN.P4_METERREADING_SUMMER WHERE READINGDATE>='2023-05-01 00:00+02:00' AND READINGDATE<='2023-05-15 00:00+02:00'")
#       2 df.head()
#
# File ~/Projects/Uni/thesis/neuro-symbolic-demand-forecasting/src/neuro_symbolic_demand_forecasting/database/snowflake.py:37, in SnowflakeDao.fetch_list(self, query)
#      35 def fetch_list(self, query: str) -> polars.DataFrame:
#      36     with self.engine.connect() as conn:
# ---> 37         print("Executing query")
#      38         result = conn.execute(query)
#      39         fetched_result= result.fetchall()
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1370, in Connection.execute(self, statement, *multiparams, **params)
#    1361 if isinstance(statement, util.string_types):
#    1362     util.warn_deprecated_20(
#    1363         "Passing a string to Connection.execute() is "
#    1364         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1367         "driver-level SQL string."
#    1368     )
# -> 1370     return self._exec_driver_sql(
#    1371         statement,
#    1372         multiparams,
#    1373         params,
#    1374         _EMPTY_EXECUTION_OPTS,
#    1375         future=False,
#    1376     )
#    1378 try:
#    1379     meth = statement._execute_on_connection
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1674, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1664         (
#    1665             statement,
#    1666             distilled_params,
#    (...)
#    1670             statement, distilled_parameters, execution_options
#    1671         )
#    1673 dialect = self.dialect
# -> 1674 ret = self._execute_context(
#    1675     dialect,
#    1676     dialect.execution_ctx_cls._init_statement,
#    1677     statement,
#    1678     distilled_parameters,
#    1679     execution_options,
#    1680     statement,
#    1681     distilled_parameters,
#    1682 )
#    1684 if not future:
#    1685     if self._has_events or self.engine._has_events:
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1953, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1950             branched.close()
#    1952 except BaseException as e:
# -> 1953     self._handle_dbapi_exception(
#    1954         e, statement, parameters, cursor, context
#    1955     )
#    1957 return result
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2138, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2134         util.raise_(
#    2135             sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2136         )
#    2137     else:
# -> 2138         util.raise_(exc_info[1], with_traceback=exc_info[2])
#    2140 finally:
#    2141     del self._reentrant_error
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1910, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1908                 break
#    1909     if not evt_handled:
# -> 1910         self.dialect.do_execute(
#    1911             cursor, statement, parameters, context
#    1912         )
#    1914 if self._has_events or self.engine._has_events:
#    1915     self.dispatch.after_cursor_execute(
#    1916         self,
#    1917         cursor,
#    (...)
#    1921         context.executemany,
#    1922     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/sqlalchemy/engine/default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/cursor.py:1033, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
#    1031 if logger.getEffectiveLevel() <= logging.INFO:
#    1032     logger.info("query: [%s]", self._format_query_for_log(query))
# -> 1033 ret = self._execute_helper(query, **kwargs)
#    1034 self._sfqid = (
#    1035     ret["data"]["queryId"]
#    1036     if "data" in ret and "queryId" in ret["data"]
#    1037     else None
#    1038 )
#    1039 logger.debug(f"sfqid: {self.sfqid}")
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/cursor.py:748, in SnowflakeCursor._execute_helper(self, query, timeout, statement_params, binding_params, binding_stage, is_internal, describe_only, _no_results, _is_put_get, _no_retry)
#     746 ret: dict[str, Any] = {"data": {}}
#     747 try:
# --> 748     ret = self._connection.cmd_query(
#     749         query,
#     750         self._sequence_counter,
#     751         self._request_id,
#     752         binding_params=binding_params,
#     753         binding_stage=binding_stage,
#     754         is_file_transfer=bool(self._is_file_transfer),
#     755         statement_params=statement_params,
#     756         is_internal=is_internal,
#     757         describe_only=describe_only,
#     758         _no_results=_no_results,
#     759         _no_retry=_no_retry,
#     760         timeout=real_timeout,
#     761     )
#     762 finally:
#     763     try:
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/connection.py:1281, in SnowflakeConnection.cmd_query(self, sql, sequence_counter, request_id, binding_params, binding_stage, is_file_transfer, statement_params, is_internal, describe_only, _no_results, _update_current_object, _no_retry, timeout)
#    1272     logger.debug(
#    1273         "sql=[%s], sequence_id=[%s], is_file_transfer=[%s]",
#    1274         self._format_query_for_log(data["sqlText"]),
#    1275         data["sequenceId"],
#    1276         is_file_transfer,
#    1277     )
#    1279 url_parameters = {REQUEST_ID: request_id}
# -> 1281 ret = self.rest.request(
#    1282     "/queries/v1/query-request?" + urlencode(url_parameters),
#    1283     data,
#    1284     client=client,
#    1285     _no_results=_no_results,
#    1286     _include_retry_params=True,
#    1287     _no_retry=_no_retry,
#    1288     timeout=timeout,
#    1289 )
#    1291 if ret is None:
#    1292     ret = {"data": {}}
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/network.py:493, in SnowflakeRestful.request(self, url, body, method, client, timeout, _no_results, _include_retry_params, _no_retry)
#     491     headers[HTTP_HEADER_SERVICE_NAME] = self._connection.service_name
#     492 if method == "post":
# --> 493     return self._post_request(
#     494         url,
#     495         headers,
#     496         json.dumps(body),
#     497         token=self.token,
#     498         _no_results=_no_results,
#     499         timeout=timeout,
#     500         _include_retry_params=_include_retry_params,
#     501         no_retry=_no_retry,
#     502     )
#     503 else:
#     504     return self._get_request(
#     505         url,
#     506         headers,
#     507         token=self.token,
#     508         timeout=timeout,
#     509     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/network.py:734, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, socket_timeout, _no_results, no_retry, _include_retry_params)
#     731     ret = probe_connection(full_url)
#     732     pprint(ret)
# --> 734 ret = self.fetch(
#     735     "post",
#     736     full_url,
#     737     headers,
#     738     data=body,
#     739     timeout=timeout,
#     740     token=token,
#     741     no_retry=no_retry,
#     742     _include_retry_params=_include_retry_params,
#     743     socket_timeout=socket_timeout,
#     744 )
#     745 logger.debug(
#     746     "ret[code] = {code}, after post request".format(
#     747         code=(ret.get("code", "N/A"))
#     748     )
#     749 )
#     751 if ret.get("code") == MASTER_TOKEN_EXPIRED_GS_CODE:
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/network.py:843, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     841 retry_ctx.set_start_time()
#     842 while True:
# --> 843     ret = self._request_exec_wrapper(
#     844         session, method, full_url, headers, data, retry_ctx, **kwargs
#     845     )
#     846     if ret is not None:
#     847         return ret
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/network.py:884, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     882 full_url = SnowflakeRestful.add_request_guid(full_url)
#     883 try:
# --> 884     return_object = self._request_exec(
#     885         session=session,
#     886         method=method,
#     887         full_url=full_url,
#     888         headers=headers,
#     889         data=data,
#     890         token=token,
#     891         **kwargs,
#     892     )
#     893     if return_object is not None:
#     894         return return_object
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/network.py:1078, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication)
#    1074 download_start_time = get_time_millis()
#    1075 # socket timeout is constant. You should be able to receive
#    1076 # the response within the time. If not, ConnectReadTimeout or
#    1077 # ReadTimeout is raised.
# -> 1078 raw_ret = session.request(
#    1079     method=method,
#    1080     url=full_url,
#    1081     headers=headers,
#    1082     data=input_data,
#    1083     timeout=socket_timeout,
#    1084     verify=True,
#    1085     stream=is_raw_binary,
#    1086     auth=SnowflakeAuth(token),
#    1087 )
#    1088 download_end_time = get_time_millis()
#    1090 try:
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/vendored/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/vendored/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/vendored/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File /usr/local/Cellar/python@3.12/3.12.0/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1411, in HTTPConnection.getresponse(self)
#    1409 try:
#    1410     try:
# -> 1411         response.begin()
#    1412     except ConnectionError:
#    1413         self.close()
#
# File /usr/local/Cellar/python@3.12/3.12.0/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:324, in HTTPResponse.begin(self)
#     322 # read until we get a non-100 response
#     323 while True:
# --> 324     version, status, reason = self._read_status()
#     325     if status != CONTINUE:
#     326         break
#
# File /usr/local/Cellar/python@3.12/3.12.0/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:285, in HTTPResponse._read_status(self)
#     284 def _read_status(self):
# --> 285     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     286     if len(line) > _MAXLINE:
#     287         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.12/3.12.0/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/vendored/urllib3/contrib/pyopenssl.py:330, in WrappedSocket.recv_into(self, *args, **kwargs)
#     328         raise
#     329 except OpenSSL.SSL.WantReadError:
# --> 330     if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     331         raise timeout("The read operation timed out")
#     332     else:
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:145, in wait_for_read(sock, timeout)
#     141 def wait_for_read(sock, timeout=None):
#     142     """Waits for reading to be available on a given socket.
#     143     Returns True if the socket is readable, or False if the timeout expired.
#     144     """
# --> 145     return wait_for_socket(sock, read=True, timeout=timeout)
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:106, in poll_wait_for_socket(sock, read, write, timeout)
#     103         t *= 1000
#     104     return poll_obj.poll(t)
# --> 106 return bool(_retry_on_intr(do_poll, timeout))
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:43, in _retry_on_intr(fn, timeout)
#      42 def _retry_on_intr(fn, timeout):
# ---> 43     return fn(timeout)
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:104, in poll_wait_for_socket.<locals>.do_poll(t)
#     102 if t is not None:
#     103     t *= 1000
# --> 104 return poll_obj.poll(t)
#
# File ~/Library/Caches/pypoetry/virtualenvs/neuro-symbolic-demand-forecasting-yu9KrGz6-py3.12/lib/python3.12/site-packages/snowflake/connector/cursor.py:737, in SnowflakeCursor._execute_helper.<locals>.interrupt_handler(*_)
#     734         except (ValueError, TypeError):
#     735             # ignore failures
#     736             pass
# --> 737 raise KeyboardInterrupt
#
# KeyboardInterrupt:
